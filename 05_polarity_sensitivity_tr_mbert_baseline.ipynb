# %%
import json

import torch
import numpy as np
import matplotlib.pyplot as plt
import transformers

from collections import defaultdict #, Counter
from transformers import AutoModelForMaskedLM, AutoTokenizer

from operator import mul
from functools import reduce


device = 'cuda:0'
softmax = torch.nn.Softmax(dim=-1)
torch.manual_seed(0)
np.random.seed(0)

MODEL_NAME = 'bert-base-multilingual-uncased'
MASK_TOKEN = '[MASK]'
PAD_TOKEN = '[PAD]'
BOS_TOKEN = '[CLS]'
EOS_TOKEN = '[SEP]'

KWORDS_THING = ('hiçbir şey','hiçbir şey','hiçbir şey','hiçbir şey',)
KWORDS_BODY  = ('kimseyi','kimseyi','kimseyi','kimseyi',)
INPUT_FILE = 'tr_test_sentences_newwords.tsv'

PREFIX = 'tr_mbert'

BATCH_SIZE = 40 
assert BATCH_SIZE%4 == 0, '# important to have BATCH_SIZE%4 == 0'

RANDOM_TOKENS = 40

keywords = list(set(KWORDS_THING)|set(KWORDS_BODY))


tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.add_tokens(['[NOT]','[FEW]','[MANY]'], special_tokens=True)

model = AutoModelForMaskedLM.from_pretrained(MODEL_NAME)
device = torch.device('cuda:0')
model.to(device)
reverse_vocab = {y:x for x, y in tokenizer.vocab.items()}
# Out:
# 2021-11-11 23:03:37.585905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# let's check the number of tokens in our keywords

torch.manual_seed(0)
np.random.seed(0)

keywords2tokens = dict()

for keyword in keywords:
    tokens = tokenizer.tokenize(keyword)
    keywords2tokens[keyword] = tokens
#     keywords2random_tokens[keyword] = np.random.choice(range(max(reverse_vocab)), (TEST_CASES_PER_SIZE,len(tokens)))
    print(len(tokens), tokens)

random_tokens = dict()
for tok in ('[NOT]', '[FEW]', '[MANY]'):
    random_tokens[tok] = np.random.choice(range(max(reverse_vocab)), RANDOM_TOKENS)
# Out:
# 3 ['kim', '##sey', '##i']
# 2 ['hicbir', 'sey']

# %%
random_tokens
# Out:
# {'[NOT]': array([ 68268,  43567,  42613,  45891,  21243,  95939,  97639,  41993,
#          86293,  55026,  80471,  80966,  48600,  39512,  52620,  80186,
#          17089,  32230,  18983,  89688, 101201,  82457,  93005, 104520,
#           6921,  38804,  67699,  70608,  37619,   7877,  83966,   1871,
#          73135,   2496,  47954,  24675,  31921,  99059,    797,  49811]),
#  '[FEW]': array([68755, 80782, 90535, 81857, 52489, 84665, 41504, 49866, 84212,
#         96766, 11723, 43890, 17591, 58146, 92288, 59300, 89141, 71557,
#         20006,  3560, 90868, 61713, 96591, 45444, 46522, 86904, 20737,
#         28647, 61353, 92217, 80163, 12134, 60535, 47883, 86107, 63360,
#         51811,  9781, 19340, 27257]),
#  '[MANY]': array([ 16298,  12372,   4420, 105412,  82991,  62079,  79860, 103555,
#           7012,   9396,   3918,   9359,  44259,  23482,  15127, 101261,
#          37237,  79701,   8752,  80041,  71331,  50624,  89183,  40133,
#          93790,  55153, 102066,  62756,  90928,  81757,  84355,  99938,
#          48682,  66509,  86384,  75751,  76693,  24777,  13824,   2418])}

# %%
# parse, mask, tokenize

subj_dict = dict()
verb_dict = dict()

def mask_sent(sent, kword):
    return [BOS_TOKEN,] + tokenizer.tokenize( 
        sent.replace(kword, f'{MASK_TOKEN} '*len(keywords2tokens[kword])).replace('  ',' ') 
    ) + [EOS_TOKEN,]

tokenized_array = []
metadata_array = []

lines = [line for idx, line in enumerate(open(INPUT_FILE, encoding='utf-8'))]

np.random.seed(0)
np.random.shuffle(lines)

for idx, line in enumerate(lines):
    chunks = line.strip().split()
    tchunks = line.strip().split('\t')

    if chunks[-1]=='thing':
        kwords = KWORDS_THING
    else:
        kwords = KWORDS_BODY
    
    subj_id = int(chunks[-3])
    subject = chunks[1]
    subj_dict[subj_id] = subject
    verb_id = int(chunks[-2])
    verb1 = chunks[2]
    verb2 = chunks[8]
    verb_dict[verb_id] = (verb1, verb2)
    
    for tidx, (cl,kword) in enumerate( zip( ('aff', 'neg', 'many', 'few'), kwords ) ):
        mt_sent = mask_sent(tchunks[tidx], kword)
        tokenized_array.append( mt_sent )
        metadata_array.append( 
            (
                (cl, subj_id, verb_id, kword, chunks[-1]),
                (tchunks[tidx], mt_sent)
            )
        )

# %%
len(lines)
print(lines[40:150])
tokenized_array[4*40:4*40+50]
# Out:
# ['şairler hiçbir şey aradı.\tşairler hiçbir şey [NOT] aradı.\t[MANY] şair hiçbir şey aradı.\t[FEW] şair hiçbir şey aradı.\t294\t23\tthing\n', 'babalar kimseyi terketti.\tbabalar kimseyi [NOT] terketti.\t[MANY] baba kimseyi terketti.\t[FEW] baba kimseyi terketti.\t80\t47\tbody\n', 'bölümler kimseyi kesti.\tbölümler kimseyi [NOT] kesti.\t[MANY] bölüm kimseyi kesti.\t[FEW] bölüm kimseyi kesti.\t62\t22\tbody\n', 'doktorlar kimseyi yayınladı.\tdoktorlar kimseyi [NOT] yayınladı.\t[MANY] doktor kimseyi yayınladı.\t[FEW] doktor kimseyi yayınladı.\t269\t1\tbody\n', 'transferler kimseyi affetti.\ttransferler kimseyi [NOT] affetti.\t[MANY] transfer kimseyi affetti.\t[FEW] transfer kimseyi affetti.\t163\t49\tbody\n', 'modeller kimseyi yükseltmiş.\tmodeller kimseyi [NOT] yükseltmiş.\t[MANY] model kimseyi yükseltmiş.\t[FEW] model kimseyi yükseltmiş.\t267\t59\tbody\n', 'haklar hiçbir şey keşfetti.\thaklar hiçbir şey [NOT] keşfetti.\t[MANY] hak hiçbir şey keşfetti.\t[FEW] hak hiçbir şey keşfetti.\t98\t18\tthing\n', 'eller hiçbir şey affetti.\teller hiçbir şey [NOT] affetti.\t[MANY] el hiçbir şey affetti.\t[FEW] el hiçbir şey affetti.\t55\t49\tthing\n', 'sular hiçbir şey farketmiş.\tsular hiçbir şey [NOT] farketmiş.\t[MANY] su hiçbir şey farketmiş.\t[FEW] su hiçbir şey farketmiş.\t83\t83\tthing\n', 'sınıflar hiçbir şey sundu.\tsınıflar hiçbir şey [NOT] sundu.\t[MANY] sınıf hiçbir şey sundu.\t[FEW] sınıf hiçbir şey sundu.\t258\t5\tthing\n', 'şarkılar kimseyi öldürttü.\tşarkılar kimseyi [NOT] öldürttü.\t[MANY] şarkı kimseyi öldürttü.\t[FEW] şarkı kimseyi öldürttü.\t35\t36\tbody\n', 'iddialar kimseyi taktı.\tiddialar kimseyi [NOT] taktı.\t[MANY] iddia kimseyi taktı.\t[FEW] iddia kimseyi taktı.\t233\t29\tbody\n', 'şairler kimseyi aktardı.\tşairler kimseyi [NOT] aktardı.\t[MANY] şair kimseyi aktardı.\t[FEW] şair kimseyi aktardı.\t294\t51\tbody\n', 'katlar hiçbir şey devraldı.\tkatlar hiçbir şey [NOT] devraldı.\t[MANY] kat hiçbir şey devraldı.\t[FEW] kat hiçbir şey devraldı.\t328\t16\tthing\n', 'sesler kimseyi kaptı.\tsesler kimseyi [NOT] kaptı.\t[MANY] ses kimseyi kaptı.\t[FEW] ses kimseyi kaptı.\t116\t40\tbody\n', 'şarkılar kimseyi keşfetti.\tşarkılar kimseyi [NOT] keşfetti.\t[MANY] şarkı kimseyi keşfetti.\t[FEW] şarkı kimseyi keşfetti.\t35\t18\tbody\n', 'aileler hiçbir şey taktı.\taileler hiçbir şey [NOT] taktı.\t[MANY] aile hiçbir şey taktı.\t[FEW] aile hiçbir şey taktı.\t128\t29\tthing\n', 'modeller kimseyi tamamladı.\tmodeller kimseyi [NOT] tamamladı.\t[MANY] model kimseyi tamamladı.\t[FEW] model kimseyi tamamladı.\t267\t0\tbody\n', 'zamanlar hiçbir şey aradı.\tzamanlar hiçbir şey [NOT] aradı.\t[MANY] zaman hiçbir şey aradı.\t[FEW] zaman hiçbir şey aradı.\t26\t23\tthing\n', 'kardeşler kimseyi farketmiş.\tkardeşler kimseyi [NOT] farketmiş.\t[MANY] kardeş kimseyi farketmiş.\t[FEW] kardeş kimseyi farketmiş.\t137\t83\tbody\n', 'zamanlar kimseyi karşıladı.\tzamanlar kimseyi [NOT] karşıladı.\t[MANY] zaman kimseyi karşıladı.\t[FEW] zaman kimseyi karşıladı.\t26\t20\tbody\n', 'siteler kimseyi kaptı.\tsiteler kimseyi [NOT] kaptı.\t[MANY] site kimseyi kaptı.\t[FEW] site kimseyi kaptı.\t42\t40\tbody\n', 'kısımlar hiçbir şey onayladı.\tkısımlar hiçbir şey [NOT] onayladı.\t[MANY] kısım hiçbir şey onayladı.\t[FEW] kısım hiçbir şey onayladı.\t199\t13\tthing\n', 'yıllar hiçbir şey dolaştı.\tyıllar hiçbir şey [NOT] dolaştı.\t[MANY] yıl hiçbir şey dolaştı.\t[FEW] yıl hiçbir şey dolaştı.\t14\t25\tthing\n', 'bugünler kimseyi bıraktı.\tbugünler kimseyi [NOT] bıraktı.\t[MANY] bugün kimseyi bıraktı.\t[FEW] bugün kimseyi bıraktı.\t171\t3\tbody\n', 'işlemler kimseyi uyguladı.\tişlemler kimseyi [NOT] uyguladı.\t[MANY] işlem kimseyi uyguladı.\t[FEW] işlem kimseyi uyguladı.\t305\t72\tbody\n', 'binalar hiçbir şey vurdu.\tbinalar hiçbir şey [NOT] vurdu.\t[MANY] bina hiçbir şey vurdu.\t[FEW] bina hiçbir şey vurdu.\t286\t14\tthing\n', 'sanatçılar kimseyi keşfetti.\tsanatçılar kimseyi [NOT] keşfetti.\t[MANY] sanatçı kimseyi keşfetti.\t[FEW] sanatçı kimseyi keşfetti.\t146\t18\t ...
# [['[CLS]', 'sair', '##ler', '[MASK]', '[MASK]', 'arad', '##ı', '.', '[SEP]'],
#  ['[CLS]',
#   'sair',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'arad',
#   '##ı',
#   '.',
#   '[SEP]'],
#  ['[CLS]', '[MANY]', 'sair', '[MASK]', '[MASK]', 'arad', '##ı', '.', '[SEP]'],
#  ['[CLS]', '[FEW]', 'sair', '[MASK]', '[MASK]', 'arad', '##ı', '.', '[SEP]'],
#  ['[CLS]',
#   'baba',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'ter',
#   '##ket',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'baba',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'ter',
#   '##ket',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'baba',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'ter',
#   '##ket',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'baba',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'ter',
#   '##ket',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'bolum',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'bolum',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'kes',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'bolum',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'bolum',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'doktor',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yayın',
#   '##ladı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'doktor',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'yayın',
#   '##ladı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'doktor',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yayın',
#   '##ladı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'doktor',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yayın',
#   '##ladı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'transfer',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'transfer',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'transfer',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'transfer',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'modelle',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yu',
#   '##kse',
#   '##lt',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'modelle',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'yu',
#   '##kse',
#   '##lt',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'model',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yu',
#   '##kse',
#   '##lt',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'model',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'yu',
#   '##kse',
#   '##lt',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'hak',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'hak',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'kes',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'hak',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'hak',
#   '[MASK]',
#   '[MASK]',
#   'kes',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'eller', '[MASK]', '[MASK]', 'af', '##fet', '##ti', '.', '[SEP]'],
#  ['[CLS]',
#   'eller',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'el',
#   '[MASK]',
#   '[MASK]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'el',
#   '[MASK]',
#   '[MASK]',
#   'af',
#   '##fet',
#   '##ti',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sula',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   'far',
#   '##ket',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sula',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'far',
#   '##ket',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'su',
#   '[MASK]',
#   '[MASK]',
#   'far',
#   '##ket',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'su',
#   '[MASK]',
#   '[MASK]',
#   'far',
#   '##ket',
#   '##mis',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   's',
#   '##ını',
#   '##fla',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   'sund',
#   '##u',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   's',
#   '##ını',
#   '##fla',
#   '##r',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'sund',
#   '##u',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   's',
#   '##ını',
#   '##f',
#   '[MASK]',
#   '[MASK]',
#   'sund',
#   '##u',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   's',
#   '##ını',
#   '##f',
#   '[MASK]',
#   '[MASK]',
#   'sund',
#   '##u',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sarkı',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'oldu',
#   '##rt',
#   '##tu',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sarkı',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'oldu',
#   '##rt',
#   '##tu',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'sarkı',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'oldu',
#   '##rt',
#   '##tu',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'sarkı',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'oldu',
#   '##rt',
#   '##tu',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'iddia',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'takt',
#   '##ı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'iddia',
#   '##lar',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'takt',
#   '##ı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[MANY]',
#   'iddia',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'takt',
#   '##ı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '[FEW]',
#   'iddia',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'takt',
#   '##ı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sair',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   'akta',
#   '##rdı',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'sair',
#   '##ler',
#   '[MASK]',
#   '[MASK]',
#   '[MASK]',
#   '[NOT]',
#   'akta',
#   '##rdı',
#   '.',
#   '[SEP]']]

# %%
def assess_batch(batch, metas, r_idx):
    global scores
    batch_input_ids = []
    batch_segment_ids = []
    
    mask_positions = []
    mask_lens = []

    max_len = max(map(len,batch))
#     print('#', max_len, ' ', end='')
    
    for idx, s in enumerate(batch):
        mask_positions.append( s.index(MASK_TOKEN) )
        mask_lens.append( s.count(MASK_TOKEN) )
        
        input_ids = tokenizer.convert_tokens_to_ids(s + [PAD_TOKEN,]*(max_len-len(s)))
        for tok in ('[NOT]', '[FEW]', '[MANY]'): # replace spec tokens with random ones
            if tok in s:
                input_ids[s.index(tok)] = random_tokens[tok][r_idx]

        batch_input_ids.append( input_ids )
        batch_segment_ids.append( [0] * len(input_ids) )

    input_ids = torch.tensor(batch_input_ids, dtype=torch.long).to(device)
    segment_ids = torch.tensor(batch_segment_ids, dtype=torch.long).to(device)
    logits = model(input_ids, token_type_ids=segment_ids)[0]
    probs = softmax(logits)
    
    return [
        reduce(mul, [pr[pos+t_pos][tokenizer.vocab[tok]].cpu().detach().numpy() \
            for t_pos, tok in enumerate(keywords2tokens[meta[0][3]]) ], 1. ) \
                for pr, pos, meta in zip(probs, mask_positions, metas)
    ]
        
assess_batch(tokenized_array[128*4:130*4], metadata_array[126*4:130*4], 2)
# Out:
# [4.847156698295282e-12,
#  2.4932986574756156e-12,
#  4.288645853006497e-12,
#  3.631279956500022e-16,
#  3.5904221559642805e-14,
#  1.0963664046460451e-11,
#  1.2768981550495295e-15,
#  7.064278895697289e-16]

# %%
# assess all the sentences

scores = defaultdict(list)
for b_idx, idx in enumerate(range(0, len(tokenized_array), BATCH_SIZE)):
    if not idx%200: print(f'{idx/(len(tokenized_array)):.2%}')
#     print(idx,idx+BATCH_SIZE)
#     print(tokenized_array[idx:idx+BATCH_SIZE])
    scores[b_idx%RANDOM_TOKENS].extend( assess_batch(tokenized_array[idx:idx+BATCH_SIZE], 
                                                     metadata_array[idx:idx+BATCH_SIZE], 
                                                     b_idx%RANDOM_TOKENS) ) # here we select the set of random tokens
# Out:
# 0.00%
# 0.50%
# 1.00%
# 1.50%
# 2.00%
# 2.50%
# 3.00%
# 3.50%
# 4.00%
# 4.50%
# 5.00%
# 5.50%
# 6.00%
# 6.50%
# 7.00%
# 7.50%
# 8.00%
# 8.50%
# 9.00%
# 9.50%
# 10.00%
# 10.50%
# 11.00%
# 11.50%
# 12.00%
# 12.50%
# 13.00%
# 13.50%
# 14.00%
# 14.50%
# 15.00%
# 15.50%
# 16.00%
# 16.50%
# 17.00%
# 17.50%
# 18.00%
# 18.50%
# 19.00%
# 19.50%
# 20.00%
# 20.50%
# 21.00%
# 21.50%
# 22.00%
# 22.50%
# 23.00%
# 23.50%
# 24.00%
# 24.50%
# 25.00%
# 25.50%
# 26.00%
# 26.50%
# 27.00%
# 27.50%
# 28.00%
# 28.50%
# 29.00%
# 29.50%
# 30.00%
# 30.50%
# 31.00%
# 31.50%
# 32.00%
# 32.50%
# 33.00%
# 33.50%
# 34.00%
# 34.50%
# 35.00%
# 35.50%
# 36.00%
# 36.50%
# 37.00%
# 37.50%
# 38.00%
# 38.50%
# 39.00%
# 39.50%
# 40.00%
# 40.50%
# 41.00%
# 41.50%
# 42.00%
# 42.50%
# 43.00%
# 43.50%
# 44.00%
# 44.50%
# 45.00%
# 45.50%
# 46.00%
# 46.50%
# 47.00%
# 47.50%
# 48.00%
# 48.50%
# 49.00%
# 49.50%
# 50.00%
# 50.50%
# 51.00%
# 51.50%
# 52.00%
# 52.50%
# 53.00%
# 53.50%
# 54.00%
# 54.50%
# 55.00%
# 55.50%
# 56.00%
# 56.50%
# 57.00%
# 57.50%
# 58.00%
# 58.50%
# 59.00%
# 59.50%
# 60.00%
# 60.50%
# 61.00%
# 61.50%
# 62.00%
# 62.50%
# 63.00%
# 63.50%
# 64.00%
# 64.50%
# 65.00%
# 65.50%
# 66.00%
# 66.50%
# 67.00%
# 67.50%
# 68.00%
# 68.50%
# 69.00%
# 69.50%
# 70.00%
# 70.50%
# 71.00%
# 71.50%
# 72.00%
# 72.50%
# 73.00%
# 73.50%
# 74.00%
# 74.50%
# 75.00%
# 75.50%
# 76.00%
# 76.50%
# 77.00%
# 77.50%
# 78.00%
# 78.50%
# 79.00%
# 79.50%
# 80.00%
# 80.50%
# 81.00%
# 81.50%
# 82.00%
# 82.50%
# 83.00%
# 83.50%
# 84.00%
# 84.50%
# 85.00%
# 85.50%
# 86.00%
# 86.50%
# 87.00%
# 87.50%
# 88.00%
# 88.50%
# 89.00%
# 89.50%
# 90.00%
# 90.50%
# 91.00%
# 91.50%
# 92.00%
# 92.50%
# 93.00%
# 93.50%
# 94.00%
# 94.50%
# 95.00%
# 95.50%
# 96.00%
# 96.50%
# 97.00%
# 97.50%
# 98.00%
# 98.50%
# 99.00%
# 99.50%

# %%
np.array(scores).shape
len(scores)
len(scores[39])

# shape of score is [random_tokens_idx][ (aff_prob, neg_prob, many_prob, few_prob)*items ]
# Out:
# 1000

# %%
stats = defaultdict(lambda:defaultdict(lambda:defaultdict(list)))

for r_idx in range(RANDOM_TOKENS):
    for score, meta in zip(scores[r_idx], metadata_array):
        if meta[0][0]=='aff':
            handle = (meta[0][4], 'aff>neg')
            k_idx = 0
        if meta[0][0]=='neg':
            handle = (meta[0][4], 'aff>neg')
            k_idx = 1
        if meta[0][0]=='many':
            handle = (meta[0][4], 'many>few')
            k_idx = 0
        if meta[0][0]=='few':
            handle = (meta[0][4], 'many>few')
            k_idx = 1
        handle2 = ('both', handle[1])
        stats[handle][r_idx][k_idx].append( score )
        stats[handle2][r_idx][k_idx].append( score )

# shape of stats now is
#  [handles][random_tokens_idx][(0 for aff and many, 1 for neg and few)][items]
# where handle is one of ('body', 'aff>neg'), ('body', 'many>few'), ('both', 'aff>neg'), 
#                          ('both', 'many>few'), ('thing', 'aff>neg'), ('thing', 'many>few')

# %%
measures = dict()
for handle in sorted(stats):
    r = []
    for r_idx in range(RANDOM_TOKENS):
        r.append( np.count_nonzero(list(map(lambda x:x[0]>x[1], zip(stats[handle][r_idx][0],stats[handle][r_idx][1]))))/len(stats[handle][r_idx][0]) )
    print(handle, f'  mean {np.mean(r):0.3%} std {np.std(r):0.3%}')
    measures[handle] = r[:]
    
# shape of measures is 
#   [handles][ random_tokens_idx scores ]
# Out:
# ('body', 'aff>neg')   mean 82.744% std 14.358%
# ('body', 'many>few')   mean 54.383% std 24.815%
# ('both', 'aff>neg')   mean 83.130% std 13.910%
# ('both', 'many>few')   mean 55.210% std 24.647%
# ('thing', 'aff>neg')   mean 83.750% std 13.553%
# ('thing', 'many>few')   mean 56.536% std 24.829%

# %%
# r
plt.hist(measures[('both', 'aff>neg')])
plt.suptitle(PREFIX+' '+str(('both', 'aff>neg')))
measures.keys()
# Out:
# dict_keys([('body', 'aff>neg'), ('body', 'many>few'), ('both', 'aff>neg'), ('both', 'many>few'), ('thing', 'aff>neg'), ('thing', 'many>few')])

# %%
# r
plt.hist(measures[('both', 'many>few')])
plt.suptitle(PREFIX+' '+str(('both', 'many>few')))
measures.keys()
# Out:
# dict_keys([('body', 'aff>neg'), ('body', 'many>few'), ('both', 'aff>neg'), ('both', 'many>few'), ('thing', 'aff>neg'), ('thing', 'many>few')])

# %%
try:
    import cPickle as pickle
except ModuleNotFoundError:
    import pickle
import dill

with open(f'{PREFIX}_baseline_scores.pkl', 'wb') as f:
    pickle.dump(scores, f, pickle.HIGHEST_PROTOCOL)
with open(f'{PREFIX}_baseline_stats.pkl', 'wb') as f:
    dill.dump(stats, f)
with open(f'{PREFIX}_baseline_measures.pkl', 'wb') as f:
    pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)

# %%
try:
    import cPickle as pickle
except ModuleNotFoundError:
    import pickle
import dill

with open(f'{PREFIX}_baseline_measures.pkl', 'rb') as f:
#     pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)        
    a = pickle.load(f)
a
# Out:
# {('body', 'aff>neg'): [0.8831168831168831,
#   0.8246753246753247,
#   0.9805194805194806,
#   1.0,
#   0.7532467532467533,
#   0.922077922077922,
#   0.7727272727272727,
#   0.8441558441558441,
#   0.2597402597402597,
#   0.8701298701298701,
#   0.948051948051948,
#   0.7207792207792207,
#   0.8766233766233766,
#   0.8311688311688312,
#   0.974025974025974,
#   0.8961038961038961,
#   0.6493506493506493,
#   0.9545454545454546,
#   0.974025974025974,
#   0.922077922077922,
#   0.7272727272727273,
#   0.935064935064935,
#   0.9805194805194806,
#   0.7402597402597403,
#   0.8181818181818182,
#   0.9935064935064936,
#   0.525974025974026,
#   0.8311688311688312,
#   0.8506493506493507,
#   0.9805194805194806,
#   0.6883116883116883,
#   0.8116883116883117,
#   0.6493506493506493,
#   0.8376623376623377,
#   0.935064935064935,
#   0.8441558441558441,
#   0.7402597402597403,
#   0.7077922077922078,
#   0.9025974025974026,
#   0.7402597402597403],
#  ('body', 'many>few'): [0.6688311688311688,
#   0.12337662337662338,
#   0.9415584415584416,
#   0.5,
#   0.2792207792207792,
#   0.34415584415584416,
#   0.4155844155844156,
#   0.8051948051948052,
#   0.922077922077922,
#   0.4805194805194805,
#   0.4155844155844156,
#   0.5064935064935064,
#   0.974025974025974,
#   0.5194805194805194,
#   0.6103896103896104,
#   0.7857142857142857,
#   0.9025974025974026,
#   0.4090909090909091,
#   0.6753246753246753,
#   0.22727272727272727,
#   0.4155844155844156,
#   0.6753246753246753,
#   0.22727272727272727,
#   0.5194805194805194,
#   0.9545454545454546,
#   0.6298701298701299,
#   0.6493506493506493,
#   0.8766233766233766,
#   0.7402597402597403,
#   0.025974025974025976,
#   0.15584415584415584,
#   0.37662337662337664,
#   0.7792207792207793,
#   0.2727272727272727,
#   0.5584415584415584,
#   0.37662337662337664,
#   0.7662337662337663,
#   0.22727272727272727,
#   0.43506493506493504,
#   0.5844155844155844],
#  ('both', 'aff>neg'): [0.896,
#   0.844,
#   0.98,
#   1.0,
#   0.78,
#   0.944,
#   0.792,
#   0.848,
#   0.284,
#   0.884,
#   0.96,
#   0.76,
#   0.852,
#   0.86,
#   0.972,
#   0.916,
#   0.628,
#   0.94,
#   0.968,
#   0.924,
#   0.74,
#   0.94,
#   0.964,
#   0.748,
#   0.816,
#   0.992,
#   0.536,
#   0.844,
#   0.84,
#   0.98,
#   0.7,
#   0.788,
#   0.668,
#   0.816,
#   0.916,
#   0.848,
#   0.76,
#   0.708,
#   0.892,
#   0.724],
#  ('both', 'many>few'): [0.688,
#   0.12,
#   0.936,
#   0.52,
#   0.264,
#   0.368,
#   0.436,
#   0.816,
#   0.884,
#   0.524,
#   0.496,
#   0.536,
#   0.976,
#   0.524,
#   0.612,
#   0.808,
#   0.9,
#   0.404,
#   0.676,
#   0.272,
#   0.456,
#   0.652,
#   0.212,
#   0.528,
#   0.948,
#   0.616,
#   0.664,
#   0.9,
#   0.744,
#   0.036,
#   0.164,
#   0.4,
#   0.78,
#   0.236,
#   0.592,
#   0.34,
#   0.784,
#   0.228,
#   0.452,
#   0.592],
#  ('thing', 'aff>neg'): [0.9166666666666666,
#   0.875,
#   0.9791666666666666,
#   1.0,
#   0.8229166666666666,
#   0.9791666666666666,
#   0.8229166666666666,
#   0.8541666666666666,
#   0.3229166666666667,
#   0.90625,
#   0.9791666666666666,
#   0.8229166666666666,
#   0.8125,
#   0.90625,
#   0.96875,
#   0.9479166666666666,
#   0.59375,
#   0.9166666666666666,
#   0.9583333333333334,
#   0.9270833333333334,
#   0.7604166666666666,
#   0.9479166666666666,
#   0.9375,
#   0.7604166666666666,
#   0.8125,
#   0.9895833333333334,
#   0.5520833333333334,
#   0.8645833333333334,
#   0.8229166666666666,
#   0.9791666666666666,
#   0.71875,
#   0.75,
#   0.6979166666666666,
#   0.78125,
#   0.8854166666666666,
#   0.8541666666666666,
#   0.7916666666666666,
#   0.7083333333333334,
#   0.875,
#   0.6979166666666666],
#  ('thing', 'many>few'): [0.71875,
#   0.11458333333333333,
#   0.9270833333333334,
#   0.5520833333333334,
#   0.23958333333333334,
#   0.40625,
#   0.46875,
#   0.8333333333333334,
#   0.8229166666666666,
#   0.59375,
#   0.625,
#   0.5833333333333334,
#   0.9791666666666666,
#   0.53125,
#   0.6145833333333334,
#   0.84375,
#   0.8958333333333334,
#   0.3958333333333333,
#   0.6770833333333334,
#   0.34375,
#   0.5208333333333334,
#   0.6145833333333334,
#   0.1875,
#   0.5416666666666666,
#   0.9375,
#   0.59375,
#   0.6875,
#   0.9375,
#   0.75,
#   0.052083333333333336,
#   0.17708333333333334,
#   0.4375,
#   0.78125,
#   0.17708333333333334,
#   0.6458333333333334,
#   0.28125,
#   0.8125,
#   0.22916666666666666,
#   0.4791666666666667,
#   0.6041666666666666]}

# %%
import matplotlib.pyplot as plt

plt.hist(a[('both', 'aff>neg')], range=(0,1))
plt.suptitle(PREFIX+' '+str(('both', 'aff>neg')))
# Out:
# Text(0.5, 0.98, "tr_mbert ('both', 'aff>neg')")
